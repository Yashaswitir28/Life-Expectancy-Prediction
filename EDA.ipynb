# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import sklearn

# %%
from platform import python_version
print(python_version())
# Out:
# 3.13.1

# %%
print(np.__name__, np.__version__)
print(pd.__name__, pd.__version__)
print(sklearn.__name__, sklearn.__version__)
# Out:
# numpy 2.2.1
# pandas 2.2.3
# sklearn 1.6.1

# %%
try:
  df = pd.read_csv('LED.csv')
  df = df.drop('Unnamed: 0', axis=1)  
except KeyError:
    print("The column 'Unnamed: 0' was not found in the CSV file.")


df1 = pd.DataFrame(df)
# Out:
# The column 'Unnamed: 0' was not found in the CSV file.

# %%
df.head()
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 0  Afghanistan  2015  Developing              65.0            263.0
# 1  Afghanistan  2014  Developing              59.9            271.0
# 2  Afghanistan  2013  Developing              59.9            268.0
# 3  Afghanistan  2012  Developing              59.5            272.0
# 4  Afghanistan  2011  Developing              59.2            275.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   ...  \
# 0             62     0.01               71.279624         65.0      1154  ...
# 1             64     0.01               73.523582         62.0       492  ...
# 2             66     0.01               73.219243         64.0       430  ...
# 3             69     0.01               78.184215         67.0      2787  ...
# 4             71     0.01                7.097109         68.0      3013  ...
#
#    Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# ...

# %%
df.shape
# Out:
# (2938, 22)

# %%
df['Status'].value_counts()
# Out:
# Status
# Developing    2426
# Developed      512
# Name: count, dtype: int64

# %%
df.describe()
# Out:
#               Year  Life expectancy   Adult Mortality  infant deaths  \
# count  2938.000000       2928.000000      2928.000000    2938.000000
# mean   2007.518720         69.224932       164.796448      30.303948
# std       4.613841          9.523867       124.292079     117.926501
# min    2000.000000         36.300000         1.000000       0.000000
# 25%    2004.000000         63.100000        74.000000       0.000000
# 50%    2008.000000         72.100000       144.000000       3.000000
# 75%    2012.000000         75.700000       228.000000      22.000000
# max    2015.000000         89.000000       723.000000    1800.000000
#
#            Alcohol  percentage expenditure  Hepatitis B       Measles   \
# count  2744.000000             2938.000000  2385.000000    2938.000000
# mean      4.602861              738.251295    80.940461    2419.592240
# std       4.052413             1987.914858    25.070016   11467.272489
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2938 entries, 0 to 2937
# Data columns (total 22 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Country                          2938 non-null   object
#  1   Year                             2938 non-null   int64
#  2   Status                           2938 non-null   object
#  3   Life expectancy                  2928 non-null   float64
#  4   Adult Mortality                  2928 non-null   float64
#  5   infant deaths                    2938 non-null   int64
#  6   Alcohol                          2744 non-null   float64
#  7   percentage expenditure           2938 non-null   float64
#  8   Hepatitis B                      2385 non-null   float64
#  9   Measles                          2938 non-null   int64
#  10   BMI                             2904 non-null   float64
#  11  under-five deaths                2938 non-null   int64
# ...

# %%
f, ax = plt.subplots(figsize=(10, 7))
corr =  df.corr(numeric_only = True)
hm = sns.heatmap(round(corr,2), annot=True, ax=ax, cmap="coolwarm",fmt='.2f', vmin=-1, vmax=1)
f.subplots_adjust(top=0.83)
t= f.suptitle('Correlation Heatmap', fontsize=14)

# %%
#pairplots of highly correlated variables  
df_pp = df[['Life expectancy ','Adult Mortality']].copy()
sns.pairplot(df_pp)

# %%
#pairplots of highly correlated variables  
df_pp = df[['infant deaths','under-five deaths ']].copy()
sns.pairplot(df_pp)

# %%
#pairplots of highly correlated variables  
#pairplots of highly correlated variables  
df_pp = df[['Polio','Diphtheria ']].copy()
sns.pairplot(df_pp)

# %%
df_pp = df[[' thinness  1-19 years',' thinness 5-9 years']].copy()
sns.pairplot(df_pp)

# %%
df_pp = df[['percentage expenditure','GDP']].copy()
sns.pairplot(df_pp)

# %%
# univariate plots 

df.hist(bins=15, linewidth=1.0, xlabelsize=8, ylabelsize=8, grid=False, edgecolor='white')    
plt.tight_layout(rect=(0, 0, 2, 2))

# %%
df.columns = df.columns.str.strip()
def find_outliers(df, column):
    if df[column].dtype not in [np.float64, np.int64]:
        print(f"Column '{column}' is not numeric. Skipping outlier detection.")
        return 0, 0

    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    outliers = df[(df[column] < lower_bound) | (df[column] > upper_bound)]
    num_outliers = len(outliers)
    percent_outliers = (num_outliers / len(df)) * 100 if len(df) > 0 else 0

    return num_outliers, percent_outliers

# Ensure column names are clean
df.columns = df.columns.str.strip()

# List of columns to check
columns_to_check = [
    'life expectancy', 'Adult Mortality', 'infant deaths', 'Alcohol',
    'percentage expenditure', 'Hepatitis B', 'Measles', 'under-five deaths',
    'Polio', 'Total expenditure', 'Diphtheria', 'HIV/AIDS', 'GDP',
    'Population', 'thinness  1-19 years', 'thinness 5-9 years',
    'Income composition of resources', 'Schooling'
]

# Iterate through columns and handle missing columns gracefully
for column in columns_to_check:
    if column in df.columns:
        num_outliers, percent_outliers = find_outliers(df, column)
        print(f"---------------{column}---------------")
        print(f"Number of outliers: {num_outliers}")
        print(f"Percent of data that is outlier: {percent_outliers:.2f}%")
    else:
        print(f"Column '{column}' not found in the dataset. Skipping.")
# Out:
# Column 'life expectancy' not found in the dataset. Skipping.
# ---------------Adult Mortality---------------
# Number of outliers: 86
# Percent of data that is outlier: 2.93%
# ---------------infant deaths---------------
# Number of outliers: 315
# Percent of data that is outlier: 10.72%
# ---------------Alcohol---------------
# Number of outliers: 3
# Percent of data that is outlier: 0.10%
# ---------------percentage expenditure---------------
# Number of outliers: 389
# Percent of data that is outlier: 13.24%
# ---------------Hepatitis B---------------
# Number of outliers: 322
# Percent of data that is outlier: 10.96%
# ---------------Measles---------------
# Number of outliers: 542
# Percent of data that is outlier: 18.45%
# ---------------under-five deaths---------------
# Number of outliers: 394
# Percent of data that is outlier: 13.41%
# ---------------Polio---------------
# Number of outliers: 279
# Percent of data that is outlier: 9.50%
# ...

# %%
df3 = pd.get_dummies(df, prefix=None)
df3.head()
# Out:
#    Year  Life expectancy  Adult Mortality  infant deaths  Alcohol  \
# 0  2015             65.0            263.0             62     0.01
# 1  2014             59.9            271.0             64     0.01
# 2  2013             59.9            268.0             66     0.01
# 3  2012             59.5            272.0             69     0.01
# 4  2011             59.2            275.0             71     0.01
#
#    percentage expenditure  Hepatitis B  Measles   BMI  under-five deaths  ...  \
# 0               71.279624         65.0     1154  19.1                 83  ...
# 1               73.523582         62.0      492  18.6                 86  ...
# 2               73.219243         64.0      430  18.1                 89  ...
# 3               78.184215         67.0     2787  17.6                 93  ...
# 4                7.097109         68.0     3013  17.2                 97  ...
#
#    Country_Uruguay  Country_Uzbekistan  Country_Vanuatu  \
# ...

# %%
print('Correlations with Polio Vaccination Rate:\n')
df3[df3.columns[0:]].corr()['Polio'][:].to_frame().sort_values(by=['Polio'], ascending=False).round(2)
# Out:
# Correlations with Polio Vaccination Rate:
#                       Polio
# Polio                  1.00
# Diphtheria             0.67
# Hepatitis B            0.49
# Life expectancy        0.47
# Schooling              0.42
# ...                     ...
# under-five deaths     -0.19
# Status_Developing     -0.22
# thinness  1-19 years  -0.22
# thinness 5-9 years    -0.22
# Adult Mortality       -0.27
#
# [215 rows x 1 columns]

# %%
df.columns = df.columns.str.strip()
print('Correlations with Diphtheria Vaccination Rate:\n')
df3[df3.columns[0:]].corr()['Diphtheria'][:].to_frame().sort_values(by=['Diphtheria'], ascending=False).round(2)
# Out:
# Correlations with Diphtheria Vaccination Rate:
#                       Diphtheria
# Diphtheria                  1.00
# Polio                       0.67
# Hepatitis B                 0.61
# Life expectancy             0.48
# Schooling                   0.43
# ...                          ...
# under-five deaths          -0.20
# Status_Developing          -0.22
# thinness 5-9 years         -0.22
# thinness  1-19 years       -0.23
# Adult Mortality            -0.28
#
# [215 rows x 1 columns]

# %%
print('Correlations with Hepatitis B Vaccination Rate:\n')
df3[df3.columns[0:]].corr()['Hepatitis B'][:].to_frame().sort_values(by=['Hepatitis B'], ascending=False).round(2)
# Out:
# Correlations with Hepatitis B Vaccination Rate:
#                                                     Hepatitis B
# Hepatitis B                                                1.00
# Diphtheria                                                 0.61
# Polio                                                      0.49
# Life expectancy                                            0.26
# Schooling                                                  0.23
# ...                                                         ...
# Country_Japan                                               NaN
# Country_Norway                                              NaN
# Country_Slovenia                                            NaN
# Country_Switzerland                                         NaN
# Country_United Kingdom of Great Britain and Nor...          NaN
#
# [215 rows x 1 columns]

# %%
df.columns = df.columns.str.strip()
print('Correlations with Life Expectancy:\n')
df3[df3.columns[0:]].corr()['Life expectancy'][:].to_frame().sort_values(by=['Life expectancy'], ascending=False).round(2)
# Out:
# Correlations with Life Expectancy:
#                                  Life expectancy
# Life expectancy                             1.00
# Schooling                                   0.75
# Income composition of resources             0.72
# BMI                                         0.57
# Status_Developed                            0.48
# ...                                          ...
# Country_Niue                                 NaN
# Country_Palau                                NaN
# Country_Saint Kitts and Nevis                NaN
# Country_San Marino                           NaN
# Country_Tuvalu                               NaN
#
# [215 rows x 1 columns]

# %%
print('Correlations with Adult Mortality:\n')
df3[df3.columns[0:]].corr()['Adult Mortality'][:].to_frame().sort_values(by=['Adult Mortality'], ascending=False).round(2)
# Out:
# Correlations with Adult Mortality:
#                                Adult Mortality
# Adult Mortality                           1.00
# HIV/AIDS                                  0.52
# Status_Developing                         0.32
# thinness 5-9 years                        0.31
# thinness  1-19 years                      0.30
# ...                                        ...
# Country_Niue                               NaN
# Country_Palau                              NaN
# Country_Saint Kitts and Nevis              NaN
# Country_San Marino                         NaN
# Country_Tuvalu                             NaN
#
# [215 rows x 1 columns]

# %%
print('Correlations with Infant Deaths:\n')
df3[df3.columns[0:]].corr()['infant deaths'][:].to_frame().sort_values(by=['infant deaths'], ascending=False).round(2)
# Out:
# Correlations with Infant Deaths:
#                    infant deaths
# infant deaths               1.00
# under-five deaths           1.00
# Country_India               0.84
# Population                  0.56
# Measles                     0.50
# ...                          ...
# Diphtheria                 -0.18
# Schooling                  -0.19
# Life expectancy            -0.20
# Hepatitis B                -0.22
# BMI                        -0.23
#
# [215 rows x 1 columns]

# %%
print('Correlations with BMI:\n')
df3[df3.columns[0:]].corr()['BMI'][:].to_frame().sort_values(by=['BMI'], ascending=False).round(2)
# Out:
# Correlations with BMI:
#                                   BMI
# BMI                              1.00
# Life expectancy                  0.57
# Schooling                        0.55
# Income composition of resources  0.51
# Alcohol                          0.33
# ...                               ...
# thinness 5-9 years              -0.54
# Country_Monaco                    NaN
# Country_San Marino                NaN
# Country_South Sudan               NaN
# Country_Sudan                     NaN
#
# [215 rows x 1 columns]

# %%
for col in df.select_dtypes(include=np.number): #Select only numeric columns
    df[col] = df[col].fillna(df[col].median())

print(df.isnull().sum())
# Out:
# Country                            0
# Year                               0
# Status                             0
# Life expectancy                    0
# Adult Mortality                    0
# infant deaths                      0
# Alcohol                            0
# percentage expenditure             0
# Hepatitis B                        0
# Measles                            0
# BMI                                0
# under-five deaths                  0
# Polio                              0
# Total expenditure                  0
# Diphtheria                         0
# HIV/AIDS                           0
# GDP                                0
# Population                         0
# thinness  1-19 years               0
# thinness 5-9 years                 0
# Income composition of resources    0
# Schooling                          0
# dtype: int64

# %%
sns.lineplot(data=df, x="Year", y="Life expectancy", hue='Status').set_title('Average Life Expectancy by Year by Country Status')
# Out:
# Text(0.5, 1.0, 'Average Life Expectancy by Year by Country Status')

# %%
sns.lineplot(data=df, x="Year", y="Polio", hue='Status').set_title('Average Polio Vaccination Rate by Year by Country Status')
# Out:
# Text(0.5, 1.0, 'Average Polio Vaccination Rate by Year by Country Status')

# %%
#sns.lineplot(data=df, x="Year", y="Diphtheria ", hue='Status').set_title('Average Diphtheria Vaccination Rate by Year by Country Status')


df.columns = df.columns.str.strip()

# Create the plot
sns.lineplot(data=df, x="Year", y="Diphtheria", hue='Status').set_title(
    'Average Diphtheria Vaccination Rate by Year by Country Status'
)
# Out:
# Text(0.5, 1.0, 'Average Diphtheria Vaccination Rate by Year by Country Status')

# %%
df.columns = df.columns.str.strip()

sns.lineplot(data=df, x="Year", y="Hepatitis B", hue='Status').set_title('Average Hepatitis B Vaccination Rate by Year by Country Status')
# Out:
# Text(0.5, 1.0, 'Average Hepatitis B Vaccination Rate by Year by Country Status')

# %%
df.columns = df.columns.str.strip()

sns.lineplot(data=df, x="Year", y="BMI", hue='Status').set_title('Average % BMI Overweight by Year by Country Status')
# Out:
# Text(0.5, 1.0, 'Average % BMI Overweight by Year by Country Status')

# %%
sns.lineplot(data=df, x="Year", y="infant deaths", hue='Status').set_title('Average Infant Death Rate per 1000 by Year by Country Status')
# Out:
# Text(0.5, 1.0, 'Average Infant Death Rate per 1000 by Year by Country Status')

# %%
sns.lineplot(data=df, x="Year", y="Adult Mortality", hue='Status').set_title('Average Adult Mortality Rate per 1000 by Year by Country Status')
# Out:
# Text(0.5, 1.0, 'Average Adult Mortality Rate per 1000 by Year by Country Status')
